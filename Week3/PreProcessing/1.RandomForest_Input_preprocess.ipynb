# %%
# !pip install scikit-learn

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv("insurance_pre.csv")

# %%
dataset = pd.get_dummies(dataset, dtype=int, drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
 indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset['charges']

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 1/3, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
y_train = np.array(y_train)
y_test = np.array(y_test)
y_train = y_train.reshape(-1, 1)
y_test = y_test.reshape(-1, 1)

# %%
scy=StandardScaler()
y_train=scy.fit_transform(y_train)
y_test=scy.transform(y_test)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
#from sklearn.tree import DecisionTreeRegressor
param_grid = {'criterion':['absolute_error', 'squared_error', 'poisson', 'friedman_mse'],
'max_features': [None,'sqrt','log2'],
'n_estimators':[10,100]}
grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose = 3,n_jobs=-1)
# fitting the model for grid search
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Users\PrakashBaskaran\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 30 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 30 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\PrakashBaskaran\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\PrakashBaskaran\anaconda3\Lib\site-packages\sklearn\base.py", line 1474, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\PrakashBaskaran\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py", line 409, in fit
#     raise ValueError(
# ValueError: Some value(s) of y are negative which is not allowed for Poisson regression.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\PrakashBaskaran\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the test scores are non-finite: [0.77534588 0.78819503 0.78955263 0.79579172 0.78003163 0.79947563
#  0.78411363 0.79265236 0.78086326 0.80006372 0.79338345 0.80010685
#         nan        nan        nan        nan        nan        nan
#  0.77103041 0.79162839 0.77229641 0.80314868 0.77551296 0.80033102]
#   warnings.warn(
# C:\Users\PrakashBaskaran\anaconda3\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['absolute_error', 'squared_error',
#                                        'poisson', 'friedman_mse'],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
# print best parameter after tuning
#print(grid.best_params_)
re=grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'n_estimators': 100}:

# %%
y_pred= grid.predict(X_test)

from sklearn.metrics import r2_score
r_score=r2_score(y_test,y_pred)
r_score
# Out:
# 0.8708276276446985

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.144833      0.010181         0.001605        0.000896
# 1        1.432285      0.036189         0.012940        0.004464
# 2        0.082955      0.004319         0.002153        0.001370
# 3        0.802300      0.042092         0.010831        0.002581
# 4        0.084404      0.004703         0.001708        0.000198
# 5        0.776679      0.050327         0.011537        0.003325
# 6        0.040157      0.002015         0.002100        0.000596
# 7        0.414016      0.061320         0.009701        0.002226
# 8        0.028160      0.003352         0.001358        0.000682
# 9        0.346593      0.015448         0.011364        0.007851
# 10       0.043417      0.007802         0.001710        0.000062
# 11       0.312587      0.009866         0.013127        0.001473
# 12       0.002629      0.002425         0.000000        0.000000
# 13       0.001581      0.001390         0.000000        0.000000
# 14       0.003742      0.001714         0.000000        0.000000
# 15       0.001717      0.001102         0.000000        0.000000
# 16       0.000758      0.001042         0.000000        0.000000
# 17       0.002037      0.004074         0.000000        0.000000
# 18       0.040805      0.003453         0.001744        0.000003
# 19       0.321955      0.025138         0.007311        0.001182
# 20       0.028746      0.003901         0.001352        0.000682
# 21       0.255550      0.015764         0.011107        0.003270
# 22       0.030169      0.002984         0.002058        0.000714
# 23       0.227655      0.006337         0.005354        0.003272
#
#    param_criterion param_max_features param_n_estimators  \
# 0   absolute_error               None                 10
# 1   absolute_error               None                100
# 2   absolute_error               sqrt                 10
# 3   absolute_error               sqrt                100
# 4   absolute_error               log2                 10
# 5   absolute_error               log2                100
# 6    squared_error               None                 10
# 7    squared_error               None                100
# 8    squared_error               sqrt                 10
# 9    squared_error               sqrt                100
# 10   squared_error               log2                 10
# 11   squared_error               log2                100
# 12         poisson               None                 10
# 13         poisson               None                100
# 14         poisson               sqrt                 10
# 15         poisson               sqrt                100
# 16         poisson               log2                 10
# 17         poisson               log2                100
# 18    friedman_mse               None                 10
# 19    friedman_mse               None                100
# 20    friedman_mse               sqrt                 10
# 21    friedman_mse               sqrt                100
# 22    friedman_mse               log2                 10
# 23    friedman_mse               log2                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'absolute_error', 'max_features'...           0.778688
# 1   {'criterion': 'absolute_error', 'max_features'...           0.786860
# 2   {'criterion': 'absolute_error', 'max_features'...           0.780005
# 3   {'criterion': 'absolute_error', 'max_features'...           0.798760
# 4   {'criterion': 'absolute_error', 'max_features'...           0.788515
# 5   {'criterion': 'absolute_error', 'max_features'...           0.803074
# 6   {'criterion': 'squared_error', 'max_features':...           0.807023
# 7   {'criterion': 'squared_error', 'max_features':...           0.797438
# 8   {'criterion': 'squared_error', 'max_features':...           0.788638
# 9   {'criterion': 'squared_error', 'max_features':...           0.804371
# 10  {'criterion': 'squared_error', 'max_features':...           0.799027
# 11  {'criterion': 'squared_error', 'max_features':...           0.802368
# 12  {'criterion': 'poisson', 'max_features': None,...                NaN
# 13  {'criterion': 'poisson', 'max_features': None,...                NaN
# 14  {'criterion': 'poisson', 'max_features': 'sqrt...                NaN
# 15  {'criterion': 'poisson', 'max_features': 'sqrt...                NaN
# 16  {'criterion': 'poisson', 'max_features': 'log2...                NaN
# 17  {'criterion': 'poisson', 'max_features': 'log2...                NaN
# 18  {'criterion': 'friedman_mse', 'max_features': ...           0.779574
# 19  {'criterion': 'friedman_mse', 'max_features': ...           0.801339
# 20  {'criterion': 'friedman_mse', 'max_features': ...           0.780816
# 21  {'criterion': 'friedman_mse', 'max_features': ...           0.806658
# 22  {'criterion': 'friedman_mse', 'max_features': ...           0.770632
# 23  {'criterion': 'friedman_mse', 'max_features': ...           0.807832
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.756241           0.812736           0.770474
# 1            0.769029           0.818009           0.809678
# 2            0.789896           0.816732           0.803971
# 3            0.768828           0.834492           0.818500
# 4            0.744830           0.805908           0.798945
# 5            0.774539           0.833438           0.820852
# 6            0.740082           0.821504           0.795954
# 7            0.754705           0.836900           0.811086
# 8            0.738395           0.828109           0.805709
# 9            0.768444           0.832122           0.829754
# 10           0.749786           0.829630           0.829754
# 11           0.765929           0.839656           0.832209
# 12                NaN                NaN                NaN
# 13                NaN                NaN                NaN
# 14                NaN                NaN                NaN
# 15                NaN                NaN                NaN
# 16                NaN                NaN                NaN
# 17                NaN                NaN                NaN
# 18           0.728336           0.815188           0.775610
# 19           0.755372           0.834219           0.806174
# 20           0.715511           0.825767           0.806784
# 21           0.773206           0.835051           0.834343
# 22           0.711878           0.821372           0.833541
# 23           0.764612           0.835611           0.834949
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.758590         0.775346        0.020389               16
# 1            0.757400         0.788195        0.023099               11
# 2            0.757160         0.789553        0.020431               10
# 3            0.758377         0.795792        0.028806                6
# 4            0.761960         0.780032        0.023087               14
# 5            0.765474         0.799476        0.026082                5
# 6            0.756006         0.784114        0.030958               12
# 7            0.763133         0.792652        0.030437                8
# 8            0.743466         0.780863        0.034963               13
# 9            0.765628         0.800064        0.028682                4
# 10           0.758719         0.793383        0.033973                7
# 11           0.760372         0.800107        0.032701                3
# 12                NaN              NaN             NaN               19
# 13                NaN              NaN             NaN               19
# 14                NaN              NaN             NaN               19
# 15                NaN              NaN             NaN               19
# 16                NaN              NaN             NaN               19
# 17                NaN              NaN             NaN               19
# 18           0.756444         0.771030        0.028564               18
# 19           0.761038         0.791628        0.029564                9
# 20           0.732604         0.772296        0.042240               17
# 21           0.766485         0.803149        0.029134                1
# 22           0.740141         0.775513        0.046464               15
# 23           0.758651         0.800331        0.033204                2

# %%
import pickle
filename = "finalized_GS_RF_input_preprocess.sav"
sfilename = "input_scaler_model.pkl"
sofilename = "output_scaler_model.pkl"
pickle.dump(grid, open(filename, 'wb'))

# Save the input scaler
pickle.dump(sc, open(sfilename, 'wb'))
# Save the output scaler
pickle.dump(scy, open(sofilename, 'wb'))

# %%
loaded_modal = pickle.load(open(filename, 'rb'))
loaded_scalar = pickle.load(open(sfilename, 'rb'))
loaded_output_scalar = pickle.load(open(sofilename, 'rb'))
preinput = loaded_scalar.transform([[32,28,1,0,1]])
preinput
# Out:
# C:\Users\PrakashBaskaran\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[-0.53875174, -0.43183433, -0.0755796 , -0.98885138,  2.00280702]])

# %%
result = loaded_modal.predict(preinput)
result
# Out:
# array([0.67755544])

# %%
preoutput = loaded_output_scalar.inverse_transform([result])
preoutput
# Out:
# array([[21143.6403275]])
