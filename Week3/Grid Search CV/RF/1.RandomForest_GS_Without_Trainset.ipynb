# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv("insurance_pre.csv")

# %%
dataset = pd.get_dummies(dataset, dtype=int, drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
 indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset['charges']

# %%
 from sklearn.ensemble import RandomForestRegressor

# %%
 from sklearn.model_selection import GridSearchCV
param_grid = {'criterion':['absolute_error', 'squared_error', 'poisson', 'friedman_mse'],
'max_features': [None,'sqrt','log2'],
'n_estimators':[10,100]}
grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose = 3,n_jobs=-1)
# fitting the model for grid search
grid.fit(indep, dep)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['absolute_error', 'squared_error',
#                                        'poisson', 'friedman_mse'],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
# print best parameter after tuning
#print(grid.best_params_)
re=grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'criterion': 'friedman_mse', 'max_features': 'log2', 'n_estimators': 100}:

# %%
y_pred= grid.predict(indep)

from sklearn.metrics import r2_score
r_score=r2_score(dep,y_pred)
r_score
# Out:
# 0.9766304339799681

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.254932      0.003282         0.006255        0.001317
# 1        7.807178      0.168798         0.100381        0.007304
# 2        0.131824      0.005309         0.004602        0.000895
# 3        4.076247      0.295400         0.099704        0.010424
# 4        0.145686      0.009859         0.003549        0.000562
# 5        4.667832      0.252854         0.097123        0.004704
# 6        0.103434      0.074932         0.010626        0.010784
# 7        2.354769      0.062568         0.096497        0.004166
# 8        0.191056      0.005932         0.024624        0.002016
# 9        1.810330      0.031424         0.100364        0.005738
# 10       0.200745      0.007597         0.027206        0.005606
# 11       1.848353      0.064246         0.107093        0.011246
# 12       0.312407      0.014674         0.024134        0.004745
# 13       2.721527      0.040887         0.085250        0.007874
# 14       0.235897      0.010171         0.028040        0.005507
# 15       2.035645      0.016964         0.086767        0.003488
# 16       0.248038      0.011049         0.030124        0.004888
# 17       1.958974      0.033414         0.097375        0.005821
# 18       0.246354      0.010813         0.027000        0.005839
# 19       2.240174      0.023287         0.052432        0.005636
# 20       0.197289      0.008976         0.022660        0.002776
# 21       1.723017      0.028756         0.087842        0.013763
# 22       0.193548      0.009802         0.021822        0.001956
# 23       1.578897      0.027627         0.053969        0.015647
#
#    param_criterion param_max_features param_n_estimators  \
# 0   absolute_error               None                 10
# 1   absolute_error               None                100
# 2   absolute_error               sqrt                 10
# 3   absolute_error               sqrt                100
# 4   absolute_error               log2                 10
# 5   absolute_error               log2                100
# 6    squared_error               None                 10
# 7    squared_error               None                100
# 8    squared_error               sqrt                 10
# 9    squared_error               sqrt                100
# 10   squared_error               log2                 10
# 11   squared_error               log2                100
# 12         poisson               None                 10
# 13         poisson               None                100
# 14         poisson               sqrt                 10
# 15         poisson               sqrt                100
# 16         poisson               log2                 10
# 17         poisson               log2                100
# 18    friedman_mse               None                 10
# 19    friedman_mse               None                100
# 20    friedman_mse               sqrt                 10
# 21    friedman_mse               sqrt                100
# 22    friedman_mse               log2                 10
# 23    friedman_mse               log2                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'absolute_error', 'max_features'...           0.820084
# 1   {'criterion': 'absolute_error', 'max_features'...           0.840545
# 2   {'criterion': 'absolute_error', 'max_features'...           0.846785
# 3   {'criterion': 'absolute_error', 'max_features'...           0.860797
# 4   {'criterion': 'absolute_error', 'max_features'...           0.841056
# 5   {'criterion': 'absolute_error', 'max_features'...           0.857972
# 6   {'criterion': 'squared_error', 'max_features':...           0.842034
# 7   {'criterion': 'squared_error', 'max_features':...           0.847761
# 8   {'criterion': 'squared_error', 'max_features':...           0.839783
# 9   {'criterion': 'squared_error', 'max_features':...           0.861342
# 10  {'criterion': 'squared_error', 'max_features':...           0.851461
# 11  {'criterion': 'squared_error', 'max_features':...           0.857777
# 12  {'criterion': 'poisson', 'max_features': None,...           0.833399
# 13  {'criterion': 'poisson', 'max_features': None,...           0.847995
# 14  {'criterion': 'poisson', 'max_features': 'sqrt...           0.841298
# 15  {'criterion': 'poisson', 'max_features': 'sqrt...           0.857476
# 16  {'criterion': 'poisson', 'max_features': 'log2...           0.836599
# 17  {'criterion': 'poisson', 'max_features': 'log2...           0.855596
# 18  {'criterion': 'friedman_mse', 'max_features': ...           0.830031
# 19  {'criterion': 'friedman_mse', 'max_features': ...           0.844686
# 20  {'criterion': 'friedman_mse', 'max_features': ...           0.839342
# 21  {'criterion': 'friedman_mse', 'max_features': ...           0.858672
# 22  {'criterion': 'friedman_mse', 'max_features': ...           0.857567
# 23  {'criterion': 'friedman_mse', 'max_features': ...           0.859251
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.757527           0.848592           0.798621
# 1            0.769376           0.849720           0.821319
# 2            0.761287           0.852853           0.796093
# 3            0.778950           0.856325           0.830221
# 4            0.761137           0.852147           0.819559
# 5            0.782567           0.858134           0.828039
# 6            0.746590           0.845918           0.802555
# 7            0.769679           0.858075           0.821315
# 8            0.770489           0.853648           0.810296
# 9            0.776893           0.857613           0.830336
# 10           0.772384           0.843352           0.813224
# 11           0.779190           0.860012           0.824457
# 12           0.757191           0.847121           0.805900
# 13           0.767201           0.857315           0.818664
# 14           0.759763           0.858953           0.814037
# 15           0.779948           0.861992           0.828360
# 16           0.763103           0.855669           0.813558
# 17           0.778735           0.859484           0.830271
# 18           0.761452           0.851278           0.813895
# 19           0.773188           0.854658           0.816420
# 20           0.775828           0.841365           0.818416
# 21           0.780014           0.863569           0.825915
# 22           0.758253           0.859558           0.817567
# 23           0.784449           0.863199           0.829795
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.822090         0.809383        0.030391               24
# 1            0.833628         0.822918        0.028330               13
# 2            0.840252         0.819454        0.035282               17
# 3            0.843802         0.834019        0.029521                2
# 4            0.811823         0.817144        0.031521               20
# 5            0.840004         0.833343        0.027827                4
# 6            0.813846         0.810189        0.035797               23
# 7            0.838159         0.826998        0.031110                9
# 8            0.820975         0.819038        0.028514               18
# 9            0.839188         0.833074        0.030340                6
# 10           0.820346         0.820154        0.027743               16
# 11           0.840809         0.832449        0.029569                8
# 12           0.826366         0.813996        0.031366               22
# 13           0.837487         0.825732        0.031960               10
# 14           0.819204         0.818651        0.033546               19
# 15           0.839683         0.833492        0.029391                3
# 16           0.839398         0.821665        0.032215               15
# 17           0.841123         0.833042        0.029086                7
# 18           0.825890         0.816509        0.030059               21
# 19           0.836078         0.825006        0.028803               11
# 20           0.834348         0.821860        0.024384               14
# 21           0.838039         0.833242        0.029921                5
# 22           0.822169         0.823023        0.036753               12
# 23           0.838396         0.835018        0.028204                1

# %%
import pickle
filename = "finalized_GS_RF_without_train_set.sav"
pickle.dump(grid, open(filename, 'wb'))

# %%
loaded_modal = pickle.load(open(filename, 'rb'))
age_input = 32
bmi_input = 28
children_input = 1
sex_male_input = 1
smoker_yes_input = 1
result = loaded_modal.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
# Out:
# C:\Users\PrakashBaskaran\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([20109.205474])
