# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv("insurance_pre.csv")

# %%
dataset = pd.get_dummies(dataset, dtype=int, drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
 indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset['charges']

# %%
 from sklearn.ensemble import RandomForestRegressor

# %%
 from sklearn.model_selection import GridSearchCV
param_grid = {'criterion':['absolute_error', 'squared_error', 'poisson', 'friedman_mse'],
'max_features': [None,'sqrt','log2'],
'n_estimators':[10,100]}
grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose = 3,n_jobs=-1)
# fitting the model for grid search
grid.fit(indep, dep)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['absolute_error', 'squared_error',
#                                        'poisson', 'friedman_mse'],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
# print best parameter after tuning
#print(grid.best_params_)
re=grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'criterion': 'absolute_error', 'max_features': 'log2', 'n_estimators': 100}:

# %%
y_pred= grid.predict(indep)

from sklearn.metrics import r2_score
r_score=r2_score(dep,y_pred)
r_score
# Out:
# 0.9685938365664061

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.251122      0.024516         0.004168        0.000866
# 1        7.784946      0.367638         0.083631        0.006437
# 2        0.147651      0.012231         0.004469        0.000718
# 3        4.435774      0.226278         0.083905        0.006278
# 4        0.192172      0.081529         0.014164        0.010660
# 5        5.197091      0.187730         0.081223        0.001803
# 6        0.242097      0.008507         0.023474        0.005861
# 7        2.167802      0.051317         0.082902        0.006922
# 8        0.180804      0.012334         0.025528        0.005105
# 9        1.595115      0.013458         0.082616        0.006795
# 10       0.169882      0.002946         0.021901        0.003821
# 11       1.603431      0.022568         0.088585        0.004796
# 12       0.257020      0.009486         0.020335        0.005158
# 13       2.344197      0.021014         0.080721        0.004091
# 14       0.186634      0.008089         0.021754        0.004800
# 15       1.761610      0.026105         0.083305        0.006421
# 16       0.192648      0.005998         0.021206        0.005598
# 17       1.737568      0.004661         0.083869        0.006661
# 18       0.224193      0.010302         0.021766        0.003738
# 19       2.014111      0.034615         0.054920        0.012939
# 20       0.177312      0.001790         0.020191        0.002693
# 21       1.520463      0.017877         0.068017        0.007446
# 22       0.185865      0.007610         0.023326        0.003928
# 23       1.379798      0.030352         0.039956        0.006071
#
#    param_criterion param_max_features param_n_estimators  \
# 0   absolute_error               None                 10
# 1   absolute_error               None                100
# 2   absolute_error               sqrt                 10
# 3   absolute_error               sqrt                100
# 4   absolute_error               log2                 10
# 5   absolute_error               log2                100
# 6    squared_error               None                 10
# 7    squared_error               None                100
# 8    squared_error               sqrt                 10
# 9    squared_error               sqrt                100
# 10   squared_error               log2                 10
# 11   squared_error               log2                100
# 12         poisson               None                 10
# 13         poisson               None                100
# 14         poisson               sqrt                 10
# 15         poisson               sqrt                100
# 16         poisson               log2                 10
# 17         poisson               log2                100
# 18    friedman_mse               None                 10
# 19    friedman_mse               None                100
# 20    friedman_mse               sqrt                 10
# 21    friedman_mse               sqrt                100
# 22    friedman_mse               log2                 10
# 23    friedman_mse               log2                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'absolute_error', 'max_features'...           0.834287
# 1   {'criterion': 'absolute_error', 'max_features'...           0.840302
# 2   {'criterion': 'absolute_error', 'max_features'...           0.835418
# 3   {'criterion': 'absolute_error', 'max_features'...           0.861375
# 4   {'criterion': 'absolute_error', 'max_features'...           0.841407
# 5   {'criterion': 'absolute_error', 'max_features'...           0.858909
# 6   {'criterion': 'squared_error', 'max_features':...           0.835978
# 7   {'criterion': 'squared_error', 'max_features':...           0.846708
# 8   {'criterion': 'squared_error', 'max_features':...           0.852802
# 9   {'criterion': 'squared_error', 'max_features':...           0.857229
# 10  {'criterion': 'squared_error', 'max_features':...           0.843490
# 11  {'criterion': 'squared_error', 'max_features':...           0.860954
# 12  {'criterion': 'poisson', 'max_features': None,...           0.841550
# 13  {'criterion': 'poisson', 'max_features': None,...           0.846763
# 14  {'criterion': 'poisson', 'max_features': 'sqrt...           0.845592
# 15  {'criterion': 'poisson', 'max_features': 'sqrt...           0.856722
# 16  {'criterion': 'poisson', 'max_features': 'log2...           0.833817
# 17  {'criterion': 'poisson', 'max_features': 'log2...           0.860864
# 18  {'criterion': 'friedman_mse', 'max_features': ...           0.828746
# 19  {'criterion': 'friedman_mse', 'max_features': ...           0.845233
# 20  {'criterion': 'friedman_mse', 'max_features': ...           0.840474
# 21  {'criterion': 'friedman_mse', 'max_features': ...           0.855363
# 22  {'criterion': 'friedman_mse', 'max_features': ...           0.843354
# 23  {'criterion': 'friedman_mse', 'max_features': ...           0.853611
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.761813           0.831203           0.819097
# 1            0.767849           0.848893           0.824370
# 2            0.747171           0.857054           0.797132
# 3            0.782426           0.854089           0.827426
# 4            0.762685           0.821143           0.823537
# 5            0.784388           0.855162           0.831906
# 6            0.754775           0.836735           0.794264
# 7            0.770735           0.853880           0.821214
# 8            0.759726           0.839592           0.805818
# 9            0.782302           0.854963           0.826953
# 10           0.768086           0.820709           0.822001
# 11           0.774146           0.858670           0.828355
# 12           0.762864           0.849098           0.807064
# 13           0.775323           0.857262           0.813758
# 14           0.758146           0.846536           0.814815
# 15           0.782621           0.860660           0.829391
# 16           0.760365           0.839281           0.807717
# 17           0.775630           0.861300           0.829394
# 18           0.737955           0.848727           0.819759
# 19           0.776164           0.857705           0.817085
# 20           0.766378           0.847638           0.808356
# 21           0.780186           0.863800           0.828964
# 22           0.760953           0.854884           0.817699
# 23           0.779718           0.857099           0.826269
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.830821         0.815444        0.027311               19
# 1            0.833209         0.822925        0.028697               12
# 2            0.832296         0.813814        0.038464               21
# 3            0.842078         0.833479        0.028000                4
# 4            0.835612         0.816877        0.028114               17
# 5            0.843933         0.834859        0.026941                1
# 6            0.826576         0.809666        0.031500               24
# 7            0.838032         0.826114        0.029759               10
# 8            0.828568         0.817301        0.032653               16
# 9            0.841349         0.832559        0.027368                6
# 10           0.821062         0.815070        0.025024               20
# 11           0.837349         0.831895        0.031428                7
# 12           0.820511         0.816217        0.030567               18
# 13           0.840220         0.826665        0.029416                9
# 14           0.823660         0.817750        0.032249               15
# 15           0.835830         0.833045        0.027881                5
# 16           0.823390         0.812914        0.028391               22
# 17           0.841451         0.833728        0.031465                3
# 18           0.820459         0.811129        0.038052               23
# 19           0.833537         0.825945        0.028266               11
# 20           0.830574         0.818684        0.029316               14
# 21           0.841280         0.833919        0.029390                2
# 22           0.828646         0.821107        0.032628               13
# 23           0.838002         0.830940        0.027906                8

# %%
import pickle
filename = "finalized_GS_RF_without_train_set.sav"
pickle.dump(grid, open(filename, 'wb'))

# %%
loaded_modal = pickle.load(open(filename, 'rb'))
age_input = 32
bmi_input = 28
children_input = 1
sex_male_input = 1
smoker_yes_input = 1
result = loaded_modal.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
result1 = grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
# Out:
# C:\Users\PrakashBaskaran\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\PrakashBaskaran\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([20102.85033175])

# %%
result1
# Out:
# array([20102.85033175])
