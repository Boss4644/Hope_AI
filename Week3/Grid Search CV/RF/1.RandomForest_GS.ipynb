# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv("insurance_pre.csv")

# %%
dataset = pd.get_dummies(dataset, drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
 indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset['charges']

# %%
 from sklearn.ensemble import RandomForestRegressor

# %%
 from sklearn.model_selection import GridSearchCV
#from sklearn.tree import DecisionTreeRegressor
param_grid = {'criterion':['absolute_error', 'squared_error', 'poisson', 'friedman_mse'],
'max_features': ['auto','sqrt','log2'],
'n_estimators':[10,100]}
grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose = 3,n_jobs=-1)
# fitting the model for grid search
grid.fit(indep, dep)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Users\PrakashBaskaran\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 40 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 8 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\PrakashBaskaran\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\PrakashBaskaran\anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Users\PrakashBaskaran\anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\PrakashBaskaran\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 32 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\PrakashBaskaran\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\PrakashBaskaran\anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Users\PrakashBaskaran\anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\PrakashBaskaran\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\PrakashBaskaran\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.81593854 0.83299071 0.81762538 0.83158921
#         nan        nan 0.82036952 0.831969   0.81330166 0.83353498
#         nan        nan 0.81637115 0.83416467 0.8170669  0.83298845
#         nan        nan 0.81916334 0.83427277 0.82250415 0.83394964]
#   warnings.warn(
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['absolute_error', 'squared_error',
#                                        'poisson', 'friedman_mse'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
# print best parameter after tuning
#print(grid.best_params_)
re=grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'n_estimators': 100}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.013506      0.009620         0.000000        0.000000
# 1        0.008300      0.005707         0.000000        0.000000
# 2        0.463236      0.042507         0.016216        0.006642
# 3        4.654091      0.123023         0.070284        0.017127
# 4        0.485698      0.022369         0.018425        0.014666
# 5        4.607403      0.138229         0.042452        0.009924
# 6        0.001685      0.001405         0.000000        0.000000
# 7        0.005419      0.003018         0.000000        0.000000
# 8        0.134176      0.022367         0.022427        0.020619
# 9        1.414329      0.033679         0.072481        0.007996
# 10       0.148993      0.055242         0.035152        0.021406
# 11       1.248408      0.065528         0.053384        0.018120
# 12       0.005400      0.001513         0.000000        0.000000
# 13       0.002674      0.001771         0.000000        0.000000
# 14       0.099413      0.004757         0.012081        0.004542
# 15       1.087976      0.045236         0.054120        0.012959
# 16       0.110762      0.008928         0.011473        0.002922
# 17       1.092449      0.012158         0.047932        0.013356
# 18       0.006419      0.004047         0.000000        0.000000
# 19       0.003402      0.003746         0.000000        0.000000
# 20       0.106795      0.017333         0.014444        0.005545
# 21       0.975729      0.023430         0.043457        0.005271
# 22       0.092446      0.008510         0.012819        0.003424
# 23       0.930996      0.015995         0.044655        0.006014
#
#    param_criterion param_max_features param_n_estimators  \
# 0   absolute_error               auto                 10
# 1   absolute_error               auto                100
# 2   absolute_error               sqrt                 10
# 3   absolute_error               sqrt                100
# 4   absolute_error               log2                 10
# 5   absolute_error               log2                100
# 6    squared_error               auto                 10
# 7    squared_error               auto                100
# 8    squared_error               sqrt                 10
# 9    squared_error               sqrt                100
# 10   squared_error               log2                 10
# 11   squared_error               log2                100
# 12         poisson               auto                 10
# 13         poisson               auto                100
# 14         poisson               sqrt                 10
# 15         poisson               sqrt                100
# 16         poisson               log2                 10
# 17         poisson               log2                100
# 18    friedman_mse               auto                 10
# 19    friedman_mse               auto                100
# 20    friedman_mse               sqrt                 10
# 21    friedman_mse               sqrt                100
# 22    friedman_mse               log2                 10
# 23    friedman_mse               log2                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'absolute_error', 'max_features'...                NaN
# 1   {'criterion': 'absolute_error', 'max_features'...                NaN
# 2   {'criterion': 'absolute_error', 'max_features'...           0.836084
# 3   {'criterion': 'absolute_error', 'max_features'...           0.858289
# 4   {'criterion': 'absolute_error', 'max_features'...           0.841515
# 5   {'criterion': 'absolute_error', 'max_features'...           0.857591
# 6   {'criterion': 'squared_error', 'max_features':...                NaN
# 7   {'criterion': 'squared_error', 'max_features':...                NaN
# 8   {'criterion': 'squared_error', 'max_features':...           0.843004
# 9   {'criterion': 'squared_error', 'max_features':...           0.858317
# 10  {'criterion': 'squared_error', 'max_features':...           0.840254
# 11  {'criterion': 'squared_error', 'max_features':...           0.857779
# 12  {'criterion': 'poisson', 'max_features': 'auto...                NaN
# 13  {'criterion': 'poisson', 'max_features': 'auto...                NaN
# 14  {'criterion': 'poisson', 'max_features': 'sqrt...           0.839429
# 15  {'criterion': 'poisson', 'max_features': 'sqrt...           0.858809
# 16  {'criterion': 'poisson', 'max_features': 'log2...           0.839552
# 17  {'criterion': 'poisson', 'max_features': 'log2...           0.856747
# 18  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 19  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 20  {'criterion': 'friedman_mse', 'max_features': ...           0.835983
# 21  {'criterion': 'friedman_mse', 'max_features': ...           0.860675
# 22  {'criterion': 'friedman_mse', 'max_features': ...           0.852325
# 23  {'criterion': 'friedman_mse', 'max_features': ...           0.857345
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2            0.776944           0.825694           0.816666
# 3            0.777447           0.855854           0.829878
# 4            0.761637           0.834961           0.819643
# 5            0.776627           0.854998           0.827708
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 8            0.772997           0.839441           0.820547
# 9            0.776841           0.859170           0.827565
# 10           0.758969           0.843019           0.811440
# 11           0.781015           0.858401           0.829087
# 12                NaN                NaN                NaN
# 13                NaN                NaN                NaN
# 14           0.755671           0.838288           0.810305
# 15           0.786220           0.860834           0.826565
# 16           0.761642           0.857308           0.816846
# 17           0.783102           0.858091           0.827603
# 18                NaN                NaN                NaN
# 19                NaN                NaN                NaN
# 20           0.766700           0.851996           0.814213
# 21           0.779452           0.859892           0.828307
# 22           0.752922           0.845331           0.826651
# 23           0.779636           0.860011           0.831821
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN               17
# 1                 NaN              NaN             NaN               17
# 2            0.824304         0.815939        0.020455               15
# 3            0.843485         0.832991        0.029555                5
# 4            0.830370         0.817625        0.028888               12
# 5            0.841022         0.831589        0.029492                8
# 6                 NaN              NaN             NaN               17
# 7                 NaN              NaN             NaN               17
# 8            0.825859         0.820370        0.025101               10
# 9            0.837951         0.831969        0.030095                7
# 10           0.812827         0.813302        0.030217               16
# 11           0.841393         0.833535        0.028446                4
# 12                NaN              NaN             NaN               17
# 13                NaN              NaN             NaN               17
# 14           0.838162         0.816371        0.032274               14
# 15           0.838395         0.834165        0.027177                2
# 16           0.809987         0.817067        0.032395               13
# 17           0.839398         0.832988        0.027398                6
# 18                NaN              NaN             NaN               17
# 19                NaN              NaN             NaN               17
# 20           0.826924         0.819163        0.028976               11
# 21           0.843038         0.834273        0.029903                1
# 22           0.835291         0.822504        0.035869                9
# 23           0.840935         0.833950        0.029086                3

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 32
# BMI: 27
# Children: 2
# Sex Male 0 or 1: 0
# Smoker Yes 0 or 1: 1

# %%
import pickle
filename = "finalized_GS_RF_without_train_set.sav"
pickle.dump(grid, open(filename, 'wb'))

# %%
loaded_modal = pickle.load(open(filename, 'rb'))
result = loaded_modal.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
# Out:
# C:\Users\PrakashBaskaran\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([21018.8224005])
