# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv("insurance_pre.csv")

# %%
dataset = pd.get_dummies(dataset, dtype=int, drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
indep = dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep = dataset['charges']

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 1/3, random_state = 0)

# %%
 from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid = {'kernel':['rbf','poly','sigmoid','linear'],
'C':[10,100,1000,3000]}
grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3,n_jobs=-1)
# fitting the model for grid search
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 100, 1000, 3000],
#                          'kernel': ['rbf', 'poly', 'sigmoid', 'linear']},
#              verbose=3)

# %%
re=grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'C': 3000, 'kernel': 'poly'}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.032151      0.008630         0.017023        0.009473      10
# 1        0.033719      0.007695         0.006465        0.004034      10
# 2        0.038175      0.001961         0.005903        0.004291      10
# 3        0.028021      0.004341         0.006751        0.004060      10
# 4        0.034694      0.005326         0.016902        0.005420     100
# 5        0.030303      0.010423         0.006256        0.003747     100
# 6        0.042324      0.008858         0.009734        0.001301     100
# 7        0.039752      0.003850         0.008666        0.003963     100
# 8        0.047539      0.009092         0.016710        0.003071    1000
# 9        0.050543      0.006330         0.004647        0.003209    1000
# 10       0.046990      0.008723         0.009267        0.002624    1000
# 11       0.043065      0.005008         0.005360        0.004449    1000
# 12       0.057534      0.010659         0.025125        0.012763    3000
# 13       0.117009      0.017608         0.002648        0.003927    3000
# 14       0.058569      0.005708         0.007378        0.003142    3000
# 15       0.070098      0.007468         0.005057        0.004243    3000
#
#    param_kernel                            params  split0_test_score  \
# 0           rbf        {'C': 10, 'kernel': 'rbf'}          -0.003956
# 1          poly       {'C': 10, 'kernel': 'poly'}           0.043648
# 2       sigmoid    {'C': 10, 'kernel': 'sigmoid'}           0.043946
# 3        linear     {'C': 10, 'kernel': 'linear'}           0.387624
# 4           rbf       {'C': 100, 'kernel': 'rbf'}           0.304939
# 5          poly      {'C': 100, 'kernel': 'poly'}           0.532310
# 6       sigmoid   {'C': 100, 'kernel': 'sigmoid'}           0.491855
# 7        linear    {'C': 100, 'kernel': 'linear'}           0.596232
# 8           rbf      {'C': 1000, 'kernel': 'rbf'}           0.732079
# 9          poly     {'C': 1000, 'kernel': 'poly'}           0.798212
# 10      sigmoid  {'C': 1000, 'kernel': 'sigmoid'}           0.248266
# 11       linear   {'C': 1000, 'kernel': 'linear'}           0.686126
# 12          rbf      {'C': 3000, 'kernel': 'rbf'}           0.795353
# 13         poly     {'C': 3000, 'kernel': 'poly'}           0.805169
# 14      sigmoid  {'C': 3000, 'kernel': 'sigmoid'}          -1.651895
# 15       linear   {'C': 3000, 'kernel': 'linear'}           0.669819
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.022453          -0.119035          -0.082925
# 1            0.079780          -0.059229          -0.009498
# 2            0.082230          -0.072132          -0.027546
# 3            0.461268           0.288301           0.340540
# 4            0.318480           0.155033           0.208422
# 5            0.571466           0.474948           0.537506
# 6            0.544604           0.439299           0.468556
# 7            0.635776           0.566816           0.588799
# 8            0.715992           0.686057           0.710177
# 9            0.787019           0.823118           0.810712
# 10           0.377692           0.315321           0.291779
# 11           0.598398           0.586104           0.573860
# 12           0.772801           0.846034           0.811601
# 13           0.783163           0.852345           0.810160
# 14          -2.010670          -1.468842          -1.712109
# 15           0.588893           0.587076           0.572849
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -0.103510        -0.057395        0.056230               15
# 1           -0.050317         0.000877        0.053658               13
# 2           -0.051337        -0.004968        0.058595               14
# 3            0.297825         0.355112        0.063693               10
# 4            0.161488         0.229672        0.069604               12
# 5            0.415264         0.506299        0.055077                8
# 6            0.424226         0.473708        0.042461                9
# 7            0.537415         0.585008        0.032600                7
# 8            0.613122         0.691485        0.041876                4
# 9            0.719979         0.787808        0.036003                3
# 10           0.346175         0.315846        0.044478               11
# 11           0.556109         0.600119        0.045217                5
# 12           0.725615         0.790281        0.040189                2
# 13           0.748201         0.799808        0.034165                1
# 14          -0.961821        -1.561068        0.346643               16
# 15           0.557014         0.595130        0.039068                6

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
