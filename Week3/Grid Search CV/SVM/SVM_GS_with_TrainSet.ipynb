# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv("insurance_pre.csv")

# %%
dataset = pd.get_dummies(dataset, dtype=int, drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
indep = dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep = dataset['charges']

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 1/3, random_state = 0)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid = {'kernel':['rbf','poly','sigmoid','linear'],
'C':[10,100,1000,3000]}
grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3,n_jobs=-1)
# fitting the model for grid search
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 100, 1000, 3000],
#                          'kernel': ['rbf', 'poly', 'sigmoid', 'linear']},
#              verbose=3)

# %%
re=grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'C': 3000, 'kernel': 'linear'}:

# %%
y_pred= grid.predict(X_test)

from sklearn.metrics import r2_score
r_score=r2_score(y_test,y_pred)
r_score
# Out:
# 0.6662613638532224

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.032688      0.007894         0.019170        0.008094      10
# 1        0.037837      0.008817         0.006498        0.000965      10
# 2        0.055816      0.012596         0.016592        0.005251      10
# 3        0.038987      0.007743         0.007173        0.001821      10
# 4        0.035114      0.002221         0.014106        0.002772     100
# 5        0.036375      0.003549         0.006810        0.001694     100
# 6        0.047069      0.005758         0.010203        0.004815     100
# 7        0.092638      0.011837         0.009095        0.006989     100
# 8        0.056035      0.007006         0.027278        0.006144    1000
# 9        0.084161      0.011701         0.009690        0.004285    1000
# 10       0.078387      0.005284         0.016516        0.007105    1000
# 11       0.411047      0.050945         0.005439        0.003106    1000
# 12       0.060573      0.010080         0.023809        0.006538    3000
# 13       0.095551      0.014706         0.010748        0.006218    3000
# 14       0.056082      0.016435         0.015997        0.008243    3000
# 15       0.751107      0.088694         0.006019        0.003452    3000
#
#    param_kernel                            params  split0_test_score  \
# 0           rbf        {'C': 10, 'kernel': 'rbf'}          -0.048970
# 1          poly       {'C': 10, 'kernel': 'poly'}          -0.114842
# 2       sigmoid    {'C': 10, 'kernel': 'sigmoid'}          -0.055108
# 3        linear     {'C': 10, 'kernel': 'linear'}          -0.052374
# 4           rbf       {'C': 100, 'kernel': 'rbf'}          -0.120809
# 5          poly      {'C': 100, 'kernel': 'poly'}          -0.140822
# 6       sigmoid   {'C': 100, 'kernel': 'sigmoid'}          -0.067487
# 7        linear    {'C': 100, 'kernel': 'linear'}           0.491287
# 8           rbf      {'C': 1000, 'kernel': 'rbf'}          -0.144864
# 9          poly     {'C': 1000, 'kernel': 'poly'}          -0.114502
# 10      sigmoid  {'C': 1000, 'kernel': 'sigmoid'}          -1.112841
# 11       linear   {'C': 1000, 'kernel': 'linear'}           0.598177
# 12          rbf      {'C': 3000, 'kernel': 'rbf'}          -0.134802
# 13         poly     {'C': 3000, 'kernel': 'poly'}          -0.045967
# 14      sigmoid  {'C': 3000, 'kernel': 'sigmoid'}          -8.860598
# 15       linear   {'C': 3000, 'kernel': 'linear'}           0.637309
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0           -0.000543          -0.168834          -0.131191
# 1            0.037445          -0.223563          -0.195052
# 2           -0.026452          -0.164324          -0.124064
# 3            0.104434          -0.156399          -0.102809
# 4            0.014684          -0.253535          -0.212486
# 5            0.042217          -0.239784          -0.222862
# 6           -0.053718          -0.171856          -0.143028
# 7            0.557330           0.432315           0.466224
# 8            0.018280          -0.256335          -0.221584
# 9            0.077448          -0.207151          -0.180556
# 10          -1.226409          -0.959182          -1.208210
# 11           0.640011           0.577787           0.593864
# 12           0.036399          -0.240720          -0.203664
# 13           0.148212          -0.128646          -0.098198
# 14          -9.865236          -6.789196          -9.039003
# 15           0.657023           0.584279           0.645973
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -0.138045        -0.097516        0.062647                6
# 1           -0.149975        -0.129197        0.091268               10
# 2           -0.140386        -0.102067        0.052442                7
# 3           -0.079150        -0.057260        0.087808                5
# 4           -0.162749        -0.146979        0.092427               13
# 5           -0.163226        -0.144895        0.100445               12
# 6           -0.156114        -0.118441        0.048296                9
# 7            0.426625         0.474756        0.047502                3
# 8           -0.170006        -0.154902        0.094927               14
# 9           -0.136631        -0.112278        0.100257                8
# 10          -1.056676        -1.112664        0.098750               15
# 11           0.547330         0.591434        0.030141                2
# 12          -0.157638        -0.140085        0.095553               11
# 13          -0.064180        -0.037756        0.097225                4
# 14          -7.061474        -8.323101        1.193664               16
# 15           0.554329         0.615782        0.039610                1
