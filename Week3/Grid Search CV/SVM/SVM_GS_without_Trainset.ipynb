# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv("insurance_pre.csv")

# %%
dataset = pd.get_dummies(dataset, dtype=int, drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
indep = dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep = dataset['charges']

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid = {'kernel':['rbf','poly','sigmoid','linear'],
'C':[10,100,1000,3000]}
grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3,n_jobs=-1)
# fitting the model for grid search
grid.fit(indep, dep)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 100, 1000, 3000],
#                          'kernel': ['rbf', 'poly', 'sigmoid', 'linear']},
#              verbose=3)

# %%
re=grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'C': 1000, 'kernel': 'linear'}:

# %%
y_pred= grid.predict(indep)

from sklearn.metrics import r2_score
r_score=r2_score(dep,y_pred)
r_score
# Out:
# 0.7179049746029832

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.093194      0.013409         0.037303        0.008390      10
# 1        0.079928      0.011596         0.015707        0.002530      10
# 2        0.121702      0.024352         0.020168        0.002777      10
# 3        0.085049      0.003749         0.010993        0.002943      10
# 4        0.088993      0.011985         0.042488        0.012369     100
# 5        0.093220      0.017119         0.013987        0.002274     100
# 6        0.123479      0.017085         0.018845        0.006072     100
# 7        0.236590      0.026287         0.018806        0.006298     100
# 8        0.106593      0.019468         0.053851        0.014645    1000
# 9        0.136563      0.006562         0.020819        0.007818    1000
# 10       0.138846      0.031731         0.035660        0.006060    1000
# 11       0.680436      0.082782         0.013722        0.007581    1000
# 12       0.128310      0.012457         0.054716        0.007550    3000
# 13       0.198684      0.021150         0.020256        0.006008    3000
# 14       0.110735      0.020443         0.027369        0.006408    3000
# 15       2.902109      0.977719         0.023822        0.001424    3000
#
#    param_kernel                            params  split0_test_score  \
# 0           rbf        {'C': 10, 'kernel': 'rbf'}          -0.110409
# 1          poly       {'C': 10, 'kernel': 'poly'}          -0.125153
# 2       sigmoid    {'C': 10, 'kernel': 'sigmoid'}          -0.116743
# 3        linear     {'C': 10, 'kernel': 'linear'}          -0.018943
# 4           rbf       {'C': 100, 'kernel': 'rbf'}          -0.160182
# 5          poly      {'C': 100, 'kernel': 'poly'}          -0.132885
# 6       sigmoid   {'C': 100, 'kernel': 'sigmoid'}          -0.142455
# 7        linear    {'C': 100, 'kernel': 'linear'}           0.559313
# 8           rbf      {'C': 1000, 'kernel': 'rbf'}          -0.155430
# 9          poly     {'C': 1000, 'kernel': 'poly'}          -0.080527
# 10      sigmoid  {'C': 1000, 'kernel': 'sigmoid'}          -2.043140
# 11       linear   {'C': 1000, 'kernel': 'linear'}           0.736398
# 12          rbf      {'C': 3000, 'kernel': 'rbf'}          -0.128958
# 13         poly     {'C': 3000, 'kernel': 'poly'}           0.037700
# 14      sigmoid  {'C': 3000, 'kernel': 'sigmoid'}         -15.561853
# 15       linear   {'C': 3000, 'kernel': 'linear'}           0.677778
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0           -0.097459          -0.074488          -0.099597
# 1           -0.081505          -0.111907          -0.131602
# 2           -0.119312          -0.085214          -0.108210
# 3            0.029886           0.022167           0.003112
# 4           -0.107253          -0.123430          -0.137753
# 5           -0.082461          -0.129220          -0.139962
# 6           -0.160831          -0.117544          -0.137984
# 7            0.521798           0.547691           0.538805
# 8           -0.098267          -0.123724          -0.137137
# 9           -0.028469          -0.073376          -0.086611
# 10          -2.686121          -2.194563          -2.210858
# 11           0.675162           0.680002           0.699377
# 12          -0.075578          -0.100199          -0.116051
# 13           0.098496           0.049291           0.035615
# 14         -20.498908         -17.095474         -16.750877
# 15           0.626814           0.732806           0.633479
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -0.124428        -0.101276        0.016459                7
# 1           -0.179328        -0.125899        0.031794               10
# 2           -0.108716        -0.107639        0.012029                8
# 3           -0.066653        -0.006086        0.034672                5
# 4           -0.209551        -0.147634        0.035511               14
# 5           -0.189219        -0.134749        0.033948               11
# 6           -0.130402        -0.137843        0.014263               12
# 7            0.508518         0.535225        0.018122                3
# 8           -0.206405        -0.144193        0.036262               13
# 9           -0.134493        -0.080695        0.033795                6
# 10          -1.942521        -2.215441        0.255409               15
# 11           0.677952         0.693778        0.022955                1
# 12          -0.179304        -0.120018        0.034578                9
# 13          -0.020924         0.040035        0.038064                4
# 14         -15.012168       -16.983856        1.914783               16
# 15           0.698692         0.673914        0.039876                2
